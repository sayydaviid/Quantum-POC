# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Logger

Logger.activate(Logger)

rede = Network()
h1 = Host('arthur')
h2 = Host('david')
h3 = Host("polyan")

h1.add_connection('polyan')
h3.add_connection('arthur')
h2.add_connection('arthur')
h3.add_connection('david')

rede.add_host(h1)
rede.add_host(h2)
rede.add_host(h3)


rede.draw()

rede._graph.edges
# Out:
# 2024-05-14 15:29:30,006: Host arthur adicionado aos hosts da rede.
# 2024-05-14 15:29:30,007: Nó arthur adicionado ao grafo da rede.
# 2024-05-14 15:29:30,008: Conexões do arthur adicionados ao grafo da rede.
# 2024-05-14 15:29:30,009: Host david adicionado aos hosts da rede.
# 2024-05-14 15:29:30,009: Nó david adicionado ao grafo da rede.
# 2024-05-14 15:29:30,010: Conexões do david adicionados ao grafo da rede.
# 2024-05-14 15:29:30,010: Host polyan adicionado aos hosts da rede.
# 2024-05-14 15:29:30,011: Conexões do polyan adicionados ao grafo da rede.
# EdgeView([('arthur', 'polyan'), ('arthur', 'david'), ('polyan', 'david')])

# %%
print(rede._graph.nodes)
print(rede._graph.edges)
# Out:
# ['arthur', 'polyan']
# [('arthur', 'polyan')]
